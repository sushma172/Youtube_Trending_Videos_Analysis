# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the dataset
#
# - Here we read the dataset file which is in csv format

# %%
df=pd.read_csv('youtube_trending_data.csv')
df
# Out:
#            video_id                                              title  \
# 0       Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 1       x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 2       KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 3       UsMRgnTcchY  Dil Ko Maine Di Kasam Video | Amaal M Ft.Ariji...
# 4       WNSEXJJhKTU  Baarish (Official Video) Payal Dev,Stebin Ben ...
# ...             ...                                                ...
# 204591  1QYBiNRu1ok  정국 (Jung Kook) 'Seven (feat. Latto)' Official ...
# 204592  cb6GMt5g8TA                 Genius Minecraft 1.20 Build Hacks!
# 204593  Iy3B118Rp10        Day in My life പൊന്നൂസിന്റെ ഓരോ കാര്യങ്ങൾ 😂
# 204594  D57eZj4-X6w  ஆடி அமாவாசை 2023 - முன்னோர்கள் வழிபாடு, படையல்...
# 204595  F5Kr8Kvx7ro  भारत जोड़ते किसान - धान की रोपाई, मंजी पर रोटी ...
#
#                  publishedAt                 channelId        channelTitle  \
# ...

# %% [markdown]
# # Applying some basic functions :
# - Shape
# - Data types
# - Unique
# - nunique
# - Count
# - value_counts
# - Information
# - Describe

# %%
df.shape
# Out:
# (204596, 16)

# %%
df.dtypes
# Out:
# video_id             object
# title                object
# publishedAt          object
# channelId            object
# channelTitle         object
# categoryId            int64
# trending_date        object
# tags                 object
# view_count            int64
# likes                 int64
# dislikes              int64
# comment_count         int64
# thumbnail_link       object
# comments_disabled      bool
# ratings_disabled       bool
# description          object
# dtype: object

# %%
df['channelTitle'].unique()
# Out:
# array(['FoxStarHindi', 'Rehaan Records', 'Diljit Dosanjh', ...,
#        'Rana Hamza Saif - RHS', 'Amrita TV Archives', 'Vipul Goyal'],
#       dtype=object)

# %%
df.nunique()
# Out:
# video_id              62982
# title                 63800
# publishedAt           62398
# channelId              4249
# channelTitle           4457
# categoryId               15
# trending_date          1055
# tags                  39835
# view_count           197691
# likes                122402
# dislikes              17039
# comment_count         30046
# thumbnail_link        62983
# comments_disabled         2
# ratings_disabled          2
# description           53323
# dtype: int64

# %%
df.count()
# Out:
# video_id             204596
# title                204596
# publishedAt          204596
# channelId            204596
# channelTitle         204595
# categoryId           204596
# trending_date        204596
# tags                 204596
# view_count           204596
# likes                204596
# dislikes             204596
# comment_count        204596
# thumbnail_link       204596
# comments_disabled    204596
# ratings_disabled     204596
# description          186713
# dtype: int64

# %%
df['channelTitle'].value_counts()
# Out:
# Vijay Television       2598
# Sourav Joshi Vlogs     2049
# Sony SAB               1756
# Colors TV              1452
# Sun TV                 1298
#                        ...
# Sunny_kalra55             1
# Mayur Thakur              1
# EMPIRE VIDEO              1
# Telugu World visite       1
# Vipul Goyal               1
# Name: channelTitle, Length: 4457, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204596 entries, 0 to 204595
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   video_id           204596 non-null  object
#  1   title              204596 non-null  object
#  2   publishedAt        204596 non-null  object
#  3   channelId          204596 non-null  object
#  4   channelTitle       204595 non-null  object
#  5   categoryId         204596 non-null  int64
#  6   trending_date      204596 non-null  object
#  7   tags               204596 non-null  object
#  8   view_count         204596 non-null  int64
#  9   likes              204596 non-null  int64
#  10  dislikes           204596 non-null  int64
#  11  comment_count      204596 non-null  int64
#  12  thumbnail_link     204596 non-null  object
#  13  comments_disabled  204596 non-null  bool
#  14  ratings_disabled   204596 non-null  bool
# ...

# %%
df.describe()
# Out:
#           categoryId    view_count         likes      dislikes  comment_count
# count  204596.000000  2.045960e+05  2.045960e+05  2.045960e+05   2.045960e+05
# mean       20.867818  2.934203e+06  1.502113e+05  2.865606e+03   9.000826e+03
# std         6.023847  7.144752e+06  4.092189e+05  7.978182e+04   7.694804e+04
# min         1.000000  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%        20.000000  4.139688e+05  1.420100e+04  0.000000e+00   3.750000e+02
# 50%        24.000000  1.018428e+06  4.264100e+04  0.000000e+00   1.225000e+03
# 75%        24.000000  2.584023e+06  1.286912e+05  1.152000e+03   4.285000e+03
# max        29.000000  2.644074e+08  1.611524e+07  1.234147e+07   6.738565e+06

# %% [markdown]
# # Data Cleaning :

# %%
df.isnull().sum()
# Out:
# video_id                 0
# title                    0
# publishedAt              0
# channelId                0
# channelTitle             1
# categoryId               0
# trending_date            0
# tags                     0
# view_count               0
# likes                    0
# dislikes                 0
# comment_count            0
# thumbnail_link           0
# comments_disabled        0
# ratings_disabled         0
# description          17883
# dtype: int64

# %%
df1=df[df.isnull().any(axis=1)]
df1
# Out:
#            video_id                                              title  \
# 74      fC3G-P3QINo                 DISAPPOINTED | NEED YOUR SUPPORT |
# 211     DY7auMfX1YU  LIVE: Janmastami - Dwarka: Vhalo Maro Aaavshe ...
# 308     fC3G-P3QINo                 DISAPPOINTED | NEED YOUR SUPPORT |
# 423     l9idDZKBasY  അബുദാബിയിൽ ഇനി കുറച് ദിവസങ്ങൾ മാത്രം  || Our f...
# 424     DY7auMfX1YU  LIVE: Janmastami - Dwarka: Vhalo Maro Aaavshe ...
# ...             ...                                                ...
# 204358  Iy3B118Rp10        Day in My life പൊന്നൂസിന്റെ ഓരോ കാര്യങ്ങൾ 😂
# 204435  cOMYE6CQVOk  2 SURPRISES IN 1 VIDEO 😍 | PARENTS FROM INDIA ...
# 204505  iBpp4oqKxhs  Virat Kohli के 500 वे मैच की सनी हुई Jersey So...
# 204587  3cMSuqMr8dg  Naya Safar as “Parents” shuru | MostSpecial Mo...
# 204593  Iy3B118Rp10        Day in My life പൊന്നൂസിന്റെ ഓരോ കാര്യങ്ങൾ 😂
#
#                  publishedAt                 channelId  \
# 74      2020-08-11T09:34:58Z  UC2kBDwkqiy7zgH1-M4UtUXQ
# ...

# %%
df=df1.fillna(value=" ")

# %%
df.isnull().sum()
# Out:
# video_id             0
# title                0
# publishedAt          0
# channelId            0
# channelTitle         0
# categoryId           0
# trending_date        0
# tags                 0
# view_count           0
# likes                0
# dislikes             0
# comment_count        0
# thumbnail_link       0
# comments_disabled    0
# ratings_disabled     0
# description          0
# dtype: int64

# %%
df[df['tags']=='[None]']
# Out:
#            video_id                                              title  \
# 74      fC3G-P3QINo                 DISAPPOINTED | NEED YOUR SUPPORT |
# 308     fC3G-P3QINo                 DISAPPOINTED | NEED YOUR SUPPORT |
# 423     l9idDZKBasY  അബുദാബിയിൽ ഇനി കുറച് ദിവസങ്ങൾ മാത്രം  || Our f...
# 647     l9idDZKBasY  അബുദാബിയിൽ ഇനി കുറച് ദിവസങ്ങൾ മാത്രം  || Our f...
# 872     l9idDZKBasY  അബുദാബിയിൽ ഇനി കുറച് ദിവസങ്ങൾ മാത്രം  || Our f...
# ...             ...                                                ...
# 204343  3cMSuqMr8dg  Naya Safar as “Parents” shuru | MostSpecial Mo...
# 204358  Iy3B118Rp10        Day in My life പൊന്നൂസിന്റെ ഓരോ കാര്യങ്ങൾ 😂
# 204435  cOMYE6CQVOk  2 SURPRISES IN 1 VIDEO 😍 | PARENTS FROM INDIA ...
# 204587  3cMSuqMr8dg  Naya Safar as “Parents” shuru | MostSpecial Mo...
# 204593  Iy3B118Rp10        Day in My life പൊന്നൂസിന്റെ ഓരോ കാര്യങ്ങൾ 😂
#
#                  publishedAt                 channelId  \
# 74      2020-08-11T09:34:58Z  UC2kBDwkqiy7zgH1-M4UtUXQ
# ...

# %%
df[df['tags']=='[None]']['tags'].count()
# df.loc[df['tags'] == '[None]', 'tags'].count()
# Out:
# 15733

# %%
df.replace(to_replace='[None]',value=" ",inplace=True)

# %%
df[df['tags']=='[None]']['tags'].count()
# Out:
# 0

# %% [markdown]
# # Filtering :

# %% [markdown]
# *  ######  How many videos have more than 10 million views?

# %%
df1=df[df['view_count']>10e6]
df1.reset_index()
# Out:
#        index     video_id                                              title  \
# 0      47874  V6bpRSKjQME  Kabhi aise apne Doggy ko copy kia hai😂 #Shorts...
# 1      48040  FxQMnIrlIiE                    Bhanda fod dia😂 #Shorts #imkavy
# 2      48057  V6bpRSKjQME  Kabhi aise apne Doggy ko copy kia hai😂 #Shorts...
# 3      48216  FxQMnIrlIiE                    Bhanda fod dia😂 #Shorts #imkavy
# 4      48249  V6bpRSKjQME  Kabhi aise apne Doggy ko copy kia hai😂 #Shorts...
# ...      ...          ...                                                ...
# 2154  151519  FCGx9FcofnY  Shaadi Baad Kisike Baap Ki Nhi Chalti 😂😝 #shor...
# 2155  151535  -ckNSsWuvgw  aise logo se sawdhan rahe🙏🏻 #shorts #viral #em...
# 2156  151589  A0qzgm7kmyU  लड़की ने की सिलेंडर वाले मदद 🥺🙏 #shorts #ytsho...
# 2157  151601  15sAm0HaB6E                 Wait for revenge 😎 #shorts #bewafa
# 2158  151631  Ucw1RqoMaBE                 Papa ka mahatv #shorts #motivation
#
# ...

# %% [markdown]
#  *  ###### What are the top 10 trending videos based on maximum number of views?

# %%
top_10_trending = df.sort_values(by = 'view_count',ascending = False, ignore_index = True)[['title','publishedAt','channelTitle',
                                                                                            'view_count','likes','dislikes',
                                                                                            'comment_count']].head(10)
top_10_trending
# Out:
#                                      title           publishedAt  \
# 0       jai shree ram 🚩#shorts #ashortaday  2022-03-15T03:21:02Z
# 1       jai shree ram 🚩#shorts #ashortaday  2022-03-15T03:21:02Z
# 2       jai shree ram 🚩#shorts #ashortaday  2022-03-15T03:21:02Z
# 3       jai shree ram 🚩#shorts #ashortaday  2022-03-15T03:21:02Z
# 4       jai shree ram 🚩#shorts #ashortaday  2022-03-15T03:21:02Z
# 5  Paytm IPL 2021 Ad - The Salon (English)  2021-06-08T14:24:24Z
# 6  Paytm IPL 2021 Ad - The Salon (English)  2021-06-08T14:24:24Z
# 7   Wakt wakt ki baat h 😎🔥 #shorts #bewafa  2022-05-10T02:30:19Z
# 8       jai shree ram 🚩#shorts #ashortaday  2022-03-15T03:21:02Z
# 9  Paytm IPL 2021 Ad - The Salon (English)  2021-06-08T14:24:24Z
#
#           channelTitle  view_count    likes  dislikes  comment_count
# 0  CHANDAN ART ACADEMY   155975017  8196855         0          49866
# 1  CHANDAN ART ACADEMY   155669632  8190381         0          49819
# ...

# %% [markdown]
# *  ###### When were trending videos published? On which days of the week?

# %%
top_10_trending['publishedAt']=pd.to_datetime(top_10_trending['publishedAt'],format='%Y-%m-%d %H:%M:%S')
top_10_trending['Days']=top_10_trending['publishedAt'].dt.day_name()
top_10_trending[['publishedAt','Days']]
# Out:
#                 publishedAt     Days
# 0 2022-03-15 03:21:02+00:00  Tuesday
# 1 2022-03-15 03:21:02+00:00  Tuesday
# 2 2022-03-15 03:21:02+00:00  Tuesday
# 3 2022-03-15 03:21:02+00:00  Tuesday
# 4 2022-03-15 03:21:02+00:00  Tuesday
# 5 2021-06-08 14:24:24+00:00  Tuesday
# 6 2021-06-08 14:24:24+00:00  Tuesday
# 7 2022-05-10 02:30:19+00:00  Tuesday
# 8 2022-03-15 03:21:02+00:00  Tuesday
# 9 2021-06-08 14:24:24+00:00  Tuesday

# %% [markdown]
# *  ###### What are the trending videos which have 0-dislikes, 1 million- views,1-lakh likes and 10k commnet_counts?

# %%
df[(df['dislikes']==0) & (df['view_count']>1e6) & (df['likes']>1e5) & (df['comment_count']>1e4)].reset_index()
# Out:
#       index     video_id                                              title  \
# 0     94793  foE3Uf4MdGY                  My 20th Birthday Vlog!💃 *Haaaye*😍
# 1     95089  Hl46iLk5Hqg            Balancing Challenge - कोन पहले गिरेगा ?
# 2     95097  foE3Uf4MdGY                  My 20th Birthday Vlog!💃 *Haaaye*😍
# 3     95323  Hl46iLk5Hqg            Balancing Challenge - कोन पहले गिरेगा ?
# 4     95567  Hl46iLk5Hqg            Balancing Challenge - कोन पहले गिरेगा ?
# ..      ...          ...                                                ...
# 207  199359  -bl87AyEUtY  🇰🇷💜Dressing like Jungkook to celebrate BTS 10t...
# 208  199592  -bl87AyEUtY  🇰🇷💜Dressing like Jungkook to celebrate BTS 10t...
# 209  201215  zoEbc9w1GrE  My Child-Birth Experience❤️| Hospital me Eid m...
# 210  201463  zoEbc9w1GrE  My Child-Birth Experience❤️| Hospital me Eid m...
# 211  201725  zoEbc9w1GrE  My Child-Birth Experience❤️| Hospital me Eid m...
#
# ...

# %% [markdown]
# *  ###### What are the trending videos that have both comments_disabled	and ratings_disabled were true?

# %%
df[(df["comments_disabled"] == True) & (df["ratings_disabled"] == True)].reset_index()
# Out:
#     index     video_id                                              title  \
# 0   92986  5P_FkLTB1rk              Guess the Number 😂 Chattambees #short
# 1   92987  3mjBPo46XZI  Rahish😡😤 | sad story | Shorts | tiyaa | Heart ...
# 2  139360  6b8Ehdzb4Sc  I can Understand Your Feelings ❤️‍🩹 | Diamond ...
# 3  143059  OXr9uOQMZAg  என்ற குடும்பத்துல எல்லாரும் வந்தாச்சு 😂#prince...
# 4  143269  OXr9uOQMZAg  என்ற குடும்பத்துல எல்லாரும் வந்தாச்சு 😂#prince...
# 5  143483  OXr9uOQMZAg  என்ற குடும்பத்துல எல்லாரும் வந்தாச்சு 😂#prince...
# 6  143621  CrnSMH8NFS8  Kisi ki kami hame nahi nikalna chahiye 🥺🙏🏻 #da...
# 7  143781  OXr9uOQMZAg  என்ற குடும்பத்துல எல்லாரும் வந்தாச்சு 😂#prince...
#
#             publishedAt                 channelId            channelTitle  \
# 0  2021-12-13T13:38:22Z  UCzsNLZ9GrGXRjt0QmvWFm2Q             Chattambees
# 1  2021-12-11T06:30:30Z  UC8GAqy4ZzLwQVmsA2xh9-fw  tiyaa_ningwal_official
# 2  2022-08-04T13:10:21Z  UCjebeDgtmv4Ogg1dlmoJG_A         Diamond Couples
# ...

# %% [markdown]
# *  ######  what are the most common words in trending video titles?

# %%
def most_common(title_words):
    d={}
    for i in title_words:
        d[i]=title_words.count(i)
    return d

# %%
df1=df['title'].head(10)
title_words = list(df1.apply(lambda x: x.split()))
title_words = [x for y in title_words for x in y]
dic=most_common(title_words)
dic
# Out:
# {'Sadak': 1,
#  '2': 1,
#  '|': 23,
#  'Official': 1,
#  'Trailer': 1,
#  'Sanjay': 1,
#  'Pooja': 1,
#  'Alia': 1,
#  'Aditya': 1,
#  'Jisshu': 1,
#  'Mahesh': 1,
#  'Bhatt': 1,
#  '28': 1,
#  'Aug': 1,
#  'Kya': 1,
#  'Baat': 1,
#  'Aa': 1,
#  ':': 1,
#  'Karan': 1,
#  'Aujla': 1,
#  '(Official': 3,
#  'Video)': 3,
#  'Tania': 1,
#  'Sukh': 2,
#  'Sanghera': 2,
#  'Desi': 1,
#  'Crew': 1,
#  'Latest': 2,
#  'Punjabi': 4,
#  'Songs': 3,
#  'Diljit': 1,
#  'Dosanjh:': 1,
#  'CLASH': 1,
#  '(Official)': 1,
#  'Music': 1,
#  'Video': 3,
#  'G.O.A.T.': 1,
#  'Dil': 1,
#  'Ko': 1,
#  'Maine': 1,
#  'Di': 1,
#  'Kasam': 1,
#  'Amaal': 1,
#  'M': 1,
#  'Ft.Arijit': 1,
#  'S,Kumaar': 1,
#  'Asim': 1,
#  'R,Himanshi': 1,
#  'K|': 1,
#  'Bhushan': 1,
#  'K': 2,
#  '|Arvindr': 1,
#  'Baarish': 1,
#  'Payal': 1,
#  'Dev,Stebin': 1,
#  'Ben': 1,
#  'Mohsin': 1,
#  'Khan,': 1,
#  'Shivangi': 1,
#  'Joshi': 1,
#  '|Kunaal': 1,
#  'V|': 1,
#  'New': 2,
#  'Song': 2,
#  '2020': 3,
#  'SISTER': 1,
# ...

# %%
# printing titles which contains common word
df[df['title'].str.contains('Kambi')]['title']
# Out:
# 9        Jatti Jaandi (Official Video) | Kambi Ft. Mahi...
# 179      Jatti Jaandi (Official Video) | Kambi Ft. Mahi...
# 369      Jatti Jaandi (Official Video) | Kambi Ft. Mahi...
# 577      Jatti Jaandi (Official Video) | Kambi Ft. Mahi...
# 789      Jatti Jaandi (Official Video) | Kambi Ft. Mahi...
# 1022     Jatti Jaandi (Official Video) | Kambi Ft. Mahi...
# 1260     Jatti Jaandi (Official Video) | Kambi Ft. Mahi...
# 12272    Kinna Kardi - Kambi Rajpuria (Official Video) ...
# 12504    Kinna Kardi - Kambi Rajpuria (Official Video) ...
# 12732    Kinna Kardi - Kambi Rajpuria (Official Video) ...
# 12967    Kinna Kardi - Kambi Rajpuria (Official Video) ...
# 42440    2 Bhai (Official Video) Kambi Rajpuria ft. Sul...
# 42655    2 Bhai (Official Video) Kambi Rajpuria ft. Sul...
# 42897    2 Bhai (Official Video) Kambi Rajpuria ft. Sul...
# 43127    2 Bhai (Official Video) Kambi Rajpuria ft. Sul...
# 63149    Thooriga | Guitar Kambi Mele Nindru | Suriya, ...
# ...

# %% [markdown]
# * ###### Which videos became trend between the year 2022-2023?

# %%
df['trending_date']=pd.to_datetime(df['trending_date'],format='%Y-%m-%d %H:%M:%S')

# %%
filt=( (df['trending_date']>='2022') & (df['trending_date']<='2023'))
df.loc[filt].reset_index()
# Out:
#         index     video_id                                              title  \
# 0       96560  lwLSb1cq4gM  Pellam Vaddu Party Muddu | Extra Jabardasth|ET...
# 1       96561  Af0MJxJIAj8  Bacchi ne sahi kiya ya galat? #shorts #ytshort...
# 2       96562  4XmgqWXBnRA  Glimpse of LIGER | Vijay Deverakonda | Puri Ja...
# 3       96563  IIAq4rrV7hE  BUYING THE MOST EXPENSIVE HOUSE | GTA V GAMEPL...
# 4       96564  0K5Qx6dcC5E  Dhamaka 😱 Experiment BY @The Experiment TV @MR...
# ...       ...          ...                                                ...
# 71216  167776  -emTyzjwlyY  Dhee 15 | Championship Battle | 28th December ...
# 71217  167777  6zU6ScVNAQI               Prerna’s reaction on our new house 🏠
# 71218  167778  YxWlaYCA8MU  Jhoome Jo Pathaan Song | Shah Rukh Khan, Deepi...
# 71219  167779  3RVoeczb1o8  Let’s Surprise Mashura 🥳❤️👏 | Suhana | Basheer...
# 71220  167780  8lfcYIKhhBI  ADNAAN 07 & ANJALI ARORA! | YOUTUBE INDIA REWI...
#
# ...

# %% [markdown]
# # grouping

# %% [markdown]
# *  ###### Which trending videos appeared more than once on the trending list but with different titles?

# %%
grouped = df.groupby("video_id")
groups = []
wanted_groups = []
for key, item in grouped:
    groups.append(grouped.get_group(key))
for g in groups:
    if len(g['title'].unique()) != 1:
        wanted_groups.append(g)

wanted_groups[0]
# Out:
#            video_id                                              title  \
# 130916  -0ldvhBlL-k  Vikrant Rona Official Trailer [Kannada]  | Kic...
# 131123  -0ldvhBlL-k  Vikrant Rona Official Trailer [Kannada]  | Kic...
# 131339  -0ldvhBlL-k  Vikrant Rona Official Trailer [Kannada]  | Kic...
# 131559  -0ldvhBlL-k  Vikrant Rona Official Trailer [Kannada] | Kich...
# 131821  -0ldvhBlL-k  Vikrant Rona Official Trailer [Kannada] | Kich...
# 132062  -0ldvhBlL-k  Vikrant Rona Official Trailer [Kannada] | Kich...
# 132313  -0ldvhBlL-k  Vikrant Rona Official Trailer [Kannada] | Kich...
#
#                  publishedAt                 channelId  \
# 130916  2022-06-23T11:31:57Z  UCnSqxrSfo1sK4WZ7nBpYW1Q
# 131123  2022-06-23T11:31:57Z  UCnSqxrSfo1sK4WZ7nBpYW1Q
# 131339  2022-06-23T11:31:57Z  UCnSqxrSfo1sK4WZ7nBpYW1Q
# 131559  2022-06-23T11:31:57Z  UCnSqxrSfo1sK4WZ7nBpYW1Q
# 131821  2022-06-23T11:31:57Z  UCnSqxrSfo1sK4WZ7nBpYW1Q
# 132062  2022-06-23T11:31:57Z  UCnSqxrSfo1sK4WZ7nBpYW1Q
# ...

# %% [markdown]
# *  ###### How many videos were there in a channel with the same title?

# %%
gp1=df.groupby('channelTitle')
gp1

# %%
gp1.get_group('FoxStarHindi').reset_index()
# Out:
#     index     video_id                                              title  \
# 0       0  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 1     171  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 2     348  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 3     523  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 4     697  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 5     894  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 6    1099  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 7    1313  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 8    1548  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 9    1809  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 10   2070  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 11   6925  QPFP58rY-5w  Laxmmi Bomb | Motion Poster | Akshay Kumar | K...
# ...

# %%
gp1['title'].value_counts().loc['FoxStarHindi']
# Out:
# title
# Sadak 2 | Official Trailer | Sanjay | Pooja | Alia | Aditya | Jisshu | Mahesh Bhatt | 28 Aug            11
# Laxmmi Bomb | Motion Poster | Akshay Kumar | Kiara Advani | Raghav Lawrence | 9th November               6
# Tadap | Official Trailer | Ahan Shetty | Tara Sutaria | Sajid Nadiadwala | Milan Luthria | 3rd Dec       5
# Tadap | Official Trailer 2 | Ahan Shetty | Tara Sutaria | Sajid Nadiadwala | Milan Luthria | 3rd Dec     4
# Tadap - OFFICIAL TEASER | Ahan Shetty | Sajid Nadiadwala | Milan Luthria | 3rd Dec                       3
# Tadap - OFFICIAL TEASER | Tara Sutaria | Sajid Nadiadwala | Milan Luthria | 3rd Dec                      3
# Name: title, dtype: int64

# %% [markdown]
# * ###### top 10 channels with the highest number of videos and their corresponding maximum view counts

# %%
sd1 = df["channelTitle"].value_counts()
sd2 = df.groupby("channelTitle")["view_count"].max()
df1 = pd.concat([sd1,sd2], axis = 1, keys = ["No. of videos", "Maximum views"])
df1.head(10)
# Out:
#                     No. of videos  Maximum views
# Vijay Television             2598        8628207
# Sourav Joshi Vlogs           2049        9264239
# Sony SAB                     1756        9461125
# Colors TV                    1452       13352221
# Sun TV                       1298       82172570
# Crazy XYZ                    1226       13954941
# HAR PAL GEO                  1165       42872281
# ZEE5                         1087       12718427
# Asianet                      1068        4333909
# T-Series                      945      130124523

# %% [markdown]
# # sorting

# %% [markdown]
# *  ###### what are the top 10 channels with the most videos in the given DataFrame df?

# %%
cdf = df.groupby("channelTitle").size().reset_index(name="video_count").sort_values("video_count", ascending=False).head(10)
cdf.reset_index()
# Out:
#    index        channelTitle  video_count
# 0   4043    Vijay Television         2598
# 1   3373  Sourav Joshi Vlogs         2049
# 2   3361            Sony SAB         1756
# 3    768           Colors TV         1452
# 4   3476              Sun TV         1298
# 5    798           Crazy XYZ         1226
# 6   1374         HAR PAL GEO         1165
# 7   4219                ZEE5         1087
# 8    402             Asianet         1068
# 9   3538            T-Series          945

# %% [markdown]
# * ###### Which of the 10 titles had most number of videos ?

# %%
s = df["title"].value_counts().sort_values(ascending = False).head(10)
s
# Out:
# Kundali Bhagya                                                                                     47
# #shorts #strugglejeet                                                                              41
# An Emotional story 🥺❤️ | gogo2728 | deepesh_zo | mr_roshan | shubham | deepesh | roshan |          38
# Kundali Bhagya | कुंडली भाग्य | Monday - Friday, 9:30 PM | Promo | Zee TV                          37
# Kumkum Bhagya                                                                                      35
# Jhilli - ଝିଲ୍ଲୀ - Mon to Sat, 7.00 PM - Zee Sarthak - Watch Full Ep on Zee5-Link in Description    31
# Udaariyaan | Mon-Sun | 7.00PM | Colors                                                             29
# Kumkum Bhagya - कुमकुम भाग्य - Monday - Saturday, 9 PM - Promo - Zee TV                            25
# Badi Behan Vs Choti Behan | Sanjhalika Vlog                                                        24
# ...

# %% [markdown]
# #  aggregation

# %% [markdown]
# *  ###### What statistical metrics are computed for the columns 'categoryId', 'view_count', 'likes', 'dislikes', and 'comment_count' in   the given dataframe df?

# %%
df[['categoryId','view_count','likes','dislikes','comment_count']].agg([np.mean,np.median,np.amax])
# Out:
#         categoryId    view_count         likes      dislikes  comment_count
# mean     20.867818  2.934203e+06  1.502113e+05  2.865606e+03   9.000826e+03
# median   24.000000  1.018428e+06  4.264100e+04  0.000000e+00   1.225000e+03
# amax     29.000000  2.644074e+08  1.611524e+07  1.234147e+07   6.738565e+06

# %% [markdown]
# *  ######  Find the mean for different channelTitles based on view_count?

# %%
m = gp1["view_count"].mean().sort_values(ascending = False).head(10)
m
# Out:
# channelTitle
# Fortnite Fun TV                    7.947438e+07
# Paytm                              7.858979e+07
# Peep Peep                          7.252257e+07
# Woody & Kleiny Extra               6.936512e+07
# P2 Motivation {Palkesh Rathore}    6.234678e+07
# Big Hit Labels                     5.214980e+07
# AnthonySenpai                      4.924730e+07
# Richa sarkar                       4.815219e+07
# Austin Sprinz                      4.592942e+07
# MR.INDIAN HACKER {#Shorts}         4.373148e+07
# Name: view_count, dtype: float64

# %% [markdown]
#  *  ###### Find the median for different channelTitles based on comment_count?

# %%
m1 = gp1["comment_count"].median().sort_values(ascending = False).head(10)
m1
# Out:
# channelTitle
# Street Gang Music    415108.0
# Big Hit Labels       339346.0
# THEBLACKLABEL        245505.0
# SMTOWN               207117.0
# HYBE LABELS          190090.5
# JYP Entertainment    180814.0
# DJSnakeVEVO          178877.0
# Round2hell           144172.0
# CarryMinati          129657.0
# ShawnMendesVEVO      126381.5
# Name: comment_count, dtype: float64

# %% [markdown]
# *  ######  Find the variance for different channelTitles based on likes?

# %%
m2 = gp1["likes"].var().sort_values(ascending = False).head(10)
m2
# Out:
# channelTitle
# Big Hit Labels         2.032033e+13
# BLACKPINK              9.237972e+12
# HYBE LABELS            8.074189e+12
# CHANDAN ART ACADEMY    6.830866e+12
# officialpsy            5.614947e+12
# Charlie Puth           4.501211e+12
# Bobby chourasiya       4.378374e+12
# Coldplay               4.160886e+12
# Hombale Films          2.206434e+12
# DJSnakeVEVO            1.952404e+12
# Name: likes, dtype: float64

# %% [markdown]
# *  ###### Find the maximum value for different channelTitles based on dislikes?

# %%
m3 = gp1["dislikes"].max().sort_values(ascending = False).head(10)
m3
# Out:
# channelTitle
# FoxStarHindi              12341474
# Zee Studios                1733752
# Bharatiya Janata Party     1229004
# Desi Music Factory         1152531
# Zee Music Company          1098465
# BLACKPINK                   879354
# Big Hit Labels              756696
# Sony Music India            354290
# Jannat Zubair Rahmani       346201
# Badshah                     194148
# Name: dislikes, dtype: int64

# %%
m4= gp1["comment_count"].min().sort_values().tail(10)
m4
# Out:
# channelTitle
# dojacatVEVO                   58883
# Navrattan Music               59284
# CarryMinati                   65486
# Boston Dynamics               74035
# Stone Music Entertainment     76288
# Round2hell                    89312
# OSM RECORDS                   96215
# ShawnMendesVEVO              120073
# THEBLACKLABEL                206015
# Street Gang Music            331663
# Name: comment_count, dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# *  ######  Which channels had the largest number of trending videos? Plot it using bar plot?

# %%
cdf = df.groupby("channelTitle").size().reset_index(name="video_count").sort_values("video_count", ascending=False).head(20)
cdf.reset_index()

plt.figure(figsize=(8,8))
sns.barplot(x="video_count", y="channelTitle", data=cdf, palette=sns.cubehelix_palette(n_colors=20,reverse=True))
plt.xlabel('No of videos')
plt.ylabel('Channel')
plt.show()

# %% [markdown]
# *  ######  Which days of the week had the largest number of trending videos? Plot it using count plot?

# %%
df['Days']=pd.to_datetime(df['publishedAt'],format='%Y-%m-%d %H:%M:%S')
df['Days']=df['Days'].dt.day_name()
plt.figure(figsize=(8,8))
sns.countplot(x='Days',data=df,linewidth=5,edgecolor=sns.color_palette('dark',10),palette='plasma')
plt.xlabel('Days')
plt.ylabel('No. of videos')
plt.title('Video Uploads by Day of the Week')
plt.show()

# %% [markdown]
# *  ######  Draw a pie chart to show the percentage of channelTitles based on videocount?

# %%
cdf = df.groupby("channelTitle").size().reset_index(name="video_count").sort_values("video_count", ascending=False).head(5)
channel=cdf['channelTitle'].to_list()
count=cdf['video_count'].to_list()
plt.pie(count,labels=channel,colors=['red','blue','g','m','c'],autopct="% 1.2f%%",
                            explode=(0.2,0,0,0,0),shadow=True)
plt.title("Top 5 Channels by Video Count")
plt.show()

# %% [markdown]
# *  ###### How many trending video titles contain capitalized word? Visualize it using piechart.

# %%
def contains_capitalized_word(s):
    for w in s.split():
        if w.isupper():
            return True
    return False


df["contains_capitalized"] = df["title"].apply(contains_capitalized_word)

value_counts = df["contains_capitalized"].value_counts().to_dict()
plt.pie([value_counts[False], value_counts[True]], labels=['No', 'Yes'], 
           colors=['#003f5c', '#ffa600'], textprops={'color': '#040204'}, startangle=45)

plt.title('Title Contains Capitalized Word?')

# %% [markdown]
# *  ###### Create the correlation table between our dataset variables. Visualize it using heatmap.

# %%
df.corr()
# Out:
#                    categoryId  view_count     likes  dislikes  comment_count  \
# categoryId           1.000000   -0.132158 -0.095421 -0.010211      -0.100572
# view_count          -0.132158    1.000000  0.800348  0.119102       0.464234
# likes               -0.095421    0.800348  1.000000  0.073004       0.619872
# dislikes            -0.010211    0.119102  0.073004  1.000000       0.152660
# comment_count       -0.100572    0.464234  0.619872  0.152660       1.000000
# comments_disabled    0.034050    0.012175 -0.004471  0.000110      -0.010382
# ratings_disabled     0.018402    0.017945 -0.036691 -0.003590      -0.006818
#
#                    comments_disabled  ratings_disabled
# categoryId                  0.034050          0.018402
# view_count                  0.012175          0.017945
# likes                      -0.004471         -0.036691
# dislikes                    0.000110         -0.003590
# comment_count              -0.010382         -0.006818
# ...

# %%
h_labels = [x.replace('_', ' ').title() for x in 
            list(df.select_dtypes(include=['number', 'bool']).columns.values)]

plt.subplots(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, xticklabels=h_labels, yticklabels=h_labels,linewidths=3, linecolor='purple', cmap=sns.cubehelix_palette(as_cmap=True))
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# *  ###### Create a table that showing the number of videos with their respective years. Visualize it.

# %%
df['trending_date']=df['trending_date'].astype(str)

# %%
cdf2 = df["trending_date"].apply(lambda x: int(x[:4])).value_counts().reset_index().rename(columns={"index": "year", "trending_date": "No_of_videos"})
cdf2
# Out:
#    year  No_of_videos
# 0  2022         71056
# 1  2021         70439
# 2  2023         36980
# 3  2020         26121

# %%
sns.barplot(x="year", y="No_of_videos", data=cdf2,palette='rocket')
plt.xlabel("Year")
plt.ylabel("No. of videos")
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.title('Number of Videos per Year')
plt.show()

# %% [markdown]
# *   ###### Visualize both the comments and ratings disabled in the dataset using count plot?

# %%
plt.figure(figsize = (14,8))
plt.subplots_adjust(wspace = 0.2, hspace = 0.4,top = 0.9)

plt.subplot(2,2,1)
g = sns.countplot(x='comments_disabled', data=df,palette='icefire')
g.set_title("Comments Disabled", fontsize=16)

plt.subplot(2,2,2)
g1 = sns.countplot(x='ratings_disabled', data=df,palette='spring')
g1.set_title("Rating Disabled", fontsize=16)
plt.show()
